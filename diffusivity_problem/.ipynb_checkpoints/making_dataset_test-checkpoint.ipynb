# %%
import numpy as np

# %%
arr = np.load('../diffusion_ffno/data/try1/fields_100k.npy')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(arr[32453][0])

# %%
arr = np.random.uniform(0,1,(100_000, 2))

# %%
np.save('../diffusion_ffno/data/try1/e_bnds.npy', arr)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 np.save('inverse_problem_ffm_flax/diffusion_ffno/data/try1/e_bnds.npy', arr)
#
# File ~/anaconda3/envs/py39/lib/python3.9/site-packages/numpy/lib/npyio.py:542, in save(file, arr, allow_pickle, fix_imports)
#     540     if not file.endswith('.npy'):
#     541         file = file + '.npy'
# --> 542     file_ctx = open(file, "wb")
#     544 with file_ctx as fid:
#     545     arr = np.asanyarray(arr)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'inverse_problem_ffm_flax/diffusion_ffno/data/try1/e_bnds.npy'
